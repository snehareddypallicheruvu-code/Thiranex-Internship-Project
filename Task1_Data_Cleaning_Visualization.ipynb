# %%
import pandas as pd
df = pd.read_csv("students.csv", sep=";")
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# Check dataset information
print(df.shape)
print(df.info())
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (395, 33)
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
# ...

# %%
# Average grades visualization
plt.figure(figsize=(8,5))
average_grades = df[['G1','G2','G3']].mean()
average_grades.plot(kind='bar')
plt.title("Average Student Grades")
plt.xlabel("Exams")
plt.ylabel("Average Marks")
plt.show()

# %%
# Correlation Heatmap Dashboard
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
plt.title("Student Performance Correlation Dashboard")
plt.show()

# %%
print("PROJECT INSIGHTS")
print("------------------")
print("1. Students with higher study time generally scored better final grades.")
print("2. The dataset contained no missing values, making it clean and reliable.")
print("3. No duplicate records were found in the dataset.")
print("4. G1, G2, and G3 grades are strongly correlated with each other.")
print("5. Higher alcohol consumption showed slight negative impact on grades.")
print("6. Some students with low absences achieved better performance.")
# Out:
# PROJECT INSIGHTS
# ------------------
# 1. Students with higher study time generally scored better final grades.
# 2. The dataset contained no missing values, making it clean and reliable.
# 3. No duplicate records were found in the dataset.
# 4. G1, G2, and G3 grades are strongly correlated with each other.
# 5. Higher alcohol consumption showed slight negative impact on grades.
# 6. Some students with low absences achieved better performance.
